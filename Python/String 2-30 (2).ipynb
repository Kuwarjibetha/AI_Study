# %%
# Data Types

# %%
# 1. Immutable - numeric, string, tuples
# 2. Mutable - list, dict, set

# %%
# String - it is a sequence of character that always written ibnto quotation

# %%
s1='abcd'
print(s1,type(s1))
# Out:
# abcd <class 'str'>

# %%
s2="abcd"
print(s2,type(s2))
# Out:
# abcd <class 'str'>

# %%
s3='''hello
i
    am
Deepanshu
        verma'''

print(s3)
# Out:
# hello
# i
#     am
# Deepanshu
#         verma

# %%
s4="""hiii
i
        am
    Deepanshu
        ve
            rma
            a"""
print(s4,type(s4))
# Out:
# hiii
# i
#         am
#     Deepanshu
#         ve
#             rma
#             a <class 'str'>

# %%
first='Deepanshu'
last='verma'

full=first+' '+last # Concatebnation
print(full)
print((first+' ')*2) # repetition string
# Out:
# Deepanshu verma
# Deepanshu Deepanshu

# %%
print('My first name is',first,'and my last name is',last)
print(f"My first name is {first} and my last name is {last}") # f string
print('My first name is {} and my last name is {}'.format(first,last))
print('My first name is {} and my last name is {}'.format(last,first))
# Out:
# My first name is Deepanshu and my last name is verma
# My first name is Deepanshu and my last name is verma
# My first name is Deepanshu and my last name is verma
# My first name is verma and my last name is Deepanshu

# %%
n=int(input('enter n '))
for i in range(1,n+1):
    a=int(input(f'enter {i} no. '))
# Out:
# enter n  5
# enter 1 no.  9
# enter 2 no.  56
# enter 3 no.  36
# enter 4 no.  24
# enter 5 no.  90

# %% [markdown]
# # Indexing & Slicing

# %%
n='deepanshu @123'
# print(len(n))
# print(n[4])
# print(n[8])
# print(n[0])
# print(n[-1])
# print(n[-5])
# print(n[55])

# %%
n='deepanshu @123'
# print(n[4:8])
# print(n[3:7])
# print(n[-6:-1])
# print(n[3:-1])
# print(n[0:100])
# print(n[0:])
# print(n[:100])
# print(n[:])
# print(n[6:2])
# print(n[0:100:2])
# print(n[0:100:4])
# print(n[0:100:1])
# print(n[::1])
print(n[::-1])# reverse of string
# Out:
# 321@ uhsnapeed

# %% [markdown]
# # String Methods

# %%
s='a quick brown fox jumps over the lazy dog'
print(len(s))
# Out:
# 41

# %%
# index
print(s.index('q'))
print(s.index('a'))
# print(s.index('A'))
# Out:
# 2
# 0

# %%
# count
print(s.count('o'))
print(s.count('A'))
# Out:
# 4
# 0

# %%
# replace
s='a quick brown fox jumps over the lazy dog'
print(s.replace('fox','cat'))
# Out:
# a quick brown cat jumps over the lazy dog

# %%
s1='deepanshu'
s2='123456789'
s3='deep1234'
s4='^%*%*&*'
s5=' '

# print(s1.isalpha())
# print(s2.isdigit())
# print(s5.isspace())
# print(s2.isalnum())

# %%
s1='deepanshu'
s2='DEEPANSHU'
s3='Deepanshu'
s4='deepanshu verma'
# print(s1.islower())
# print(s2.isupper())
# print(s1.upper())
# print(s2.lower())
print(s1.capitalize())
# print(s3[0].isupper())
print(s3.istitle())
print(s4.title())
# Out:
# Deepanshu
# True
# Deepanshu Verma

# %%
s='a quick brown fox jumps over the lazy dog'
print(s.split(' '))
print(s.split('o'))
# Out:
# ['a', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# ['a quick br', 'wn f', 'x jumps ', 'ver the lazy d', 'g']

# %%
s='gDFcgRsCgCy'
print(s.swapcase())
# Out:
# GdfCGrScGcY

# %%
s='a quick brown fox jumps over the lazy dog'
print(s.startswith('a'))
print(s.endswith('og'))
print(s.lstrip('a'))
print(s.rstrip('g'))
# Out:
# True
# True
#  quick brown fox jumps over the lazy dog
# a quick brown fox jumps over the lazy do

# %% [markdown]
# # Tuples

# %%
# Tuples are my immutable data type that stores the elements comma seperatedly
# tuples are packed into the parenthesis

# %%
t=(1,2,3)
print(t)
print(type(t))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
t1=('a','b','c','d')
print(t1,type(t1))
# Out:
# ('a', 'b', 'c', 'd') <class 'tuple'>

# %%
t2=(5,)
print(t2)
print(type(t2))
# Out:
# (5,)
# <class 'tuple'>

# %%
t3=('d',)
print(t3)
print(type(t3))
# Out:
# ('d',)
# <class 'tuple'>

# %%
t4=1,2,3,4,5
print(t4)
print(type(t4))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
t1=('Deepanshu',)
t2=('verma',)
full=t1+t2
print(type(full),full)
print(t1*3)
# Out:
# <class 'tuple'> ('Deepanshu', 'verma')
# ('Deepanshu', 'Deepanshu', 'Deepanshu')

# %%
t1=('a', 'quick', 'brown', 'fox', 'jumps', 'over', 'a', 'lazy', 'dog')
print(len(t1))
# Out:
# 9

# %%
print(t1.index('a'))
print(t1.index('o'))
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 2
#       1 print(t1.index('a'))
# ----> 2 print(t1.index('o'))
#
# ValueError: tuple.index(x): x not in tuple

# %%
t1=('a', 'quick', 'brown', 'fox', 'jumps', 'over', 'a', 'lazy', 'dog')
print(t1.count('o'))
print(t1.count('a'))
# Out:
# 0
# 2

# %%
t1=(9,2,1,8,4,0)
print(sorted(t1))
print(sorted(t1,reverse=True))
print(min(t1))
print(max(t1))
print(sum(t1))
# Out:
# [0, 1, 2, 4, 8, 9]
# [9, 8, 4, 2, 1, 0]
# 0
# 9
# 24

# %%
t=('Z','a',' ','6','A','d','@')
print(sorted(t))
print(sorted(t,reverse=True))
print(min(t))
print(max(t))
# Out:
# [' ', '6', '@', 'A', 'Z', 'a', 'd']
# ['d', 'a', 'Z', 'A', '@', '6', ' ']
#
# d

# %%
for i in t:
    print(i,'.....',ord(i))
# Out:
# Z ..... 90
# a ..... 97
#   ..... 32
# 6 ..... 54
# A ..... 65
# d ..... 100
# @ ..... 64

# %%
t=1,2,3
print(t)
x,y=t
print(y)
# Out:
# (1, 2, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 3
#       1 t=1,2,3
#       2 print(t)
# ----> 3 x,y=t
#       4 print(y)
#
# ValueError: too many values to unpack (expected 2)

# %%
print(t1)
# Out:
# ('a', 'quick', 'brown', 'fox', 'jumps', 'over', 'a', 'lazy', 'dog')

# %%
print(",".join(t1))
# Out:
# a,quick,brown,fox,jumps,over,a,lazy,dog

# %%
s=input('enter s ')
if s==s[::-1]:
    print('Pallindrome')
else:
    print('Not Pallindrome')
# Out:
# enter s  121
# Pallindrome

# %%
s='deep@1234.com'
for i in s:
    if i.isalpha():
        pass
    elif i.isdigit():
        pass
    else:
        print(True)
        break
# Out:
# True

# %%
s='banana' #ban
x=''
for i in s:
    if i not in x:
        x=x+i
print(x)
# Out:
# ban

# %%
s='apple'
c=0
for i in s:
    print(i,'...',c)
    c=c+1
# Out:
# a ... 0
# p ... 1
# p ... 2
# l ... 3
# e ... 4

# %%
s='apple'
for i in range(len(s)):
    print(s[i],'....',i)
# Out:
# a .... 0
# p .... 1
# p .... 2
# l .... 3
# e .... 4

# %%
z='ant'

print(z.index('t'))
# Out:
# 2

# %%
# s='a quick brown fox jumps over the lazy dog'

# z=s.split()
# a=input('enter a ')
# n=input('enter n ')
# z[z.index(a)]=n
# print(' '.join(z))
