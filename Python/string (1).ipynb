# %%
# Data Types
# 1. Immutable - numeric, string, tuples
# 2. Mutable - list, dict, set

# %%
# n=12345
# for i in n:
#     if i==3:
#         break
#     print(i)
# print('bye')

# %%
# String - It is a sequnece of character that always be written into quotation

# %%
s1='hello'
print(s1,type(s1))
# Out:
# hello <class 'str'>

# %%
s2="hello"
print(s2,type(s2))
# Out:
# hello <class 'str'>

# %%
s3='''hello
i
    am
Deepanshu
        verma
a
    n
    d 
        i 
am 
        a
Data 
        scie
nce
        traibnerer'''

print(s3)
print(type(s3))
# Out:
# hello
# i
#     am
# Deepanshu
#         verma
# a
#     n
#     d
#         i
# am
#         a
# Data
#         scie
# nce
#         traibnerer
# <class 'str'>

# %%
s4="""hello
i
    am
Deepanshu
        verma
a
    n
    d 
        i 
am 
        a
Data 
        scie
nce
        traibnerer"""

print(s4)
# Out:
# hello
# i
#     am
# Deepanshu
#         verma
# a
#     n
#     d
#         i
# am
#         a
# Data
#         scie
# nce
#         traibnerer

# %%
first='Deepanshu'
last='Verma'
full=first+' '+last # Concatenation
print(full)

print((first+' ')*2)
# print((first+' ')*2) # repetition of String
# Out:
# Deepanshu Verma
# Deepanshu Deepanshu

# %%
print('My first name is',first,'and my last name is',last)
print(f'My first name is {first} and my last name is {last}') # f string
print('My first name is {} and my last name is {}'.format(first, last)) # format specifier
# Out:
# My first name is Deepanshu and my last name is Verma
# My first name is Deepanshu and my last name is Verma
# My first name is Deepanshu and my last name is Verma

# %%
s='aman'
print(len(s))
# Out:
# 4

# %% [markdown]
# # Indexing & Slicing

# %%
s='deepanshu @123'
# print(s,len(s))
print(s[4])
# print(s[0])
# print(s[9])
# print(s[-1])
# print(s[-5])
# print(s[100])
# Out:
# a

# %%
s='deepanshu @123'

# print(s[4:8])
# print(s[5:10])
# print(s[0:1])
# print(s[-6:-1])
# print(s[0:100])
# print(s[100:0])
# print(s[6:2])
# print(s[-2:-6])
# print(s[0:])
# print(s[:1000000])
# print(s[:])

# %%
s='deepanshu @123'
print(s[0:100:2])
print(s[3:11:4])
print(s[::5])
print(s[::1])
print(s[::-1]) # reverse of the string
# Out:
# deasu@2
# ph
# dn@
# deepanshu @123
# 321@ uhsnapeed

# %%
# String Methods
s='a quick brown fox jumps over the lazy dog'
# print(len(s))

# %%
# index
# print(s.index('i'))
# print(s.index('a'))
# print(s.index('A'))

# %%
s='a quick brown fox jumps over the lazy dog'

print(s.count('o'))
print(s.count('A'))
# replace
print(s.replace('fox','cat'))
# Out:
# 4
# 0
# a quick brown cat jumps over the lazy dog

# %%
s1='deepanshu'
s2='64263273120'
s3=' '
s4='deepanshu6448237932'
s5='%^&%'
# print(s1.isalpha())
# print(s2.isdigit())
# print(s3.isspace())
print(s2.isalnum())
# Out:
# True

# %%
s1='deepanshu'
s2='DEEPANSHU'
s3='Deepanshu'
s4='deepanshu verma'


# print(s2.islower())
# print(s1.upper())
# print(s2.isupper())
# print(s2.lower())
# print(s1.capitalize())
# print(s4.iscapitalize())
# print(s4.title())
# print(s3.istitle())
# print(s3[0].isupper())

# %%
a='FfUGhgHCfCGbNklng'
print(a.swapcase())
# Out:
# fFugHGhcFcgBnKLNG

# %%
s='a quick brown fox jumps over the lazy dog'
print(s.startswith('a'))
print(s.endswith('og'))
# Out:
# True
# True

# %%
s='a quick brown fox jumps over the lazy dog'
print(s.split(' '))
print(s.split('o'))
# Out:
# ['a', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# ['a quick br', 'wn f', 'x jumps ', 'ver the lazy d', 'g']

# %%
s='a quick brown fox jumps over the lazy dog'
print(s.lstrip('a'))
print(s.rstrip('g'))
# Out:
#  quick brown fox jumps over the lazy dog
# a quick brown fox jumps over the lazy do

# %%
n=input('enter n ')
if n==n[::-1]:
    print('Pallindromic')
else:
    print('Not Pallindromic')
# Out:
# enter n  abcd
# Not Pallindromic

# %%
n=input('enter n ')
for i in n:
    if i.isalnum():
        pass
    else:
        print(True)
        break
# Out:
# enter n  deepansdhu verma
# True

# %%
s='banana'
x=''
for i in s:
    if i not in x:
        x=x+i
print(x)
# Out:
# ban

# %%
s='a quick brown fox jumps over the lazy dog'
a=''
for i in s:
    if i.isspace():
        pass
    elif i not in a:
        a=a+i
if len(a)==26:
    print('alpahnets',a)
    # print(' '.join(sorted(a)))
else:
    print('not preswnt')
# Out:
# alpahnets aquickbrownfxjmpsvethlzydg
