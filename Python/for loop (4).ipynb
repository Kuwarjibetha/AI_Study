# %% [markdown]
# # Loops

# %%
# for loop
# while loop

# %%
# for loop
#1. when i want to iterate in a given iterable we use for loop for it
    # when i want to move charcater by character in a given sequence we use for loop foir it

#2. when i wan to do the task at certain number of times we use for loop for it

# %%
n='aman'
for i in n:
    print(i)
# Out:
# a
# m
# a
# n

# %%
n='aman'
for i in n:
    print(i)
    print('hello')
# Out:
# a
# hello
# m
# hello
# a
# hello
# n
# hello

# %%
n='aman'
for i in n:
    print(i)

print('bye')
# Out:
# a
# m
# a
# n
# bye

# %%
n='aman'
for i in n:
    print(n)
# Out:
# aman
# aman
# aman
# aman

# %%
n=input('enter name ')

for i in n:
    print(i)
print('Bye')
# Out:
# enter name  deepanshu
# d
# e
# e
# p
# a
# n
# s
# h
# u
# Bye

# %%
n='ape'
c=0
for i in n:
    c=c+1

print(c)
# Out:
# 3

# %%
n='ape'
c=0
for i in n:
    c=c+1

    print(c)
# Out:
# 1
# 2
# 3

# %%
n=input('enter n ')
c=0
for i in n:
    c=c+1
    print(i,c)
# Out:
# enter n  deepanshu
# d 1
# e 2
# e 3
# p 4
# a 5
# n 6
# s 7
# h 8
# u 9

# %%
L=[1,2,3,4,5,6,7,8,0,9]
c=0
for i in L:
    c+=1 # c=c+1

print(c)
# Out:
# 10

# %%
L=[1,2,3,4,5,6,7,8,0,9]
s=0
c=0
for i in L:
    s=s+i
    c+=1 # c=c+1

print(s/c)
# Out:
# 4.5

# %%
L=[1,2,3,4,5]
e=0
o=0
for i in L:
    if i%2==0:
        e=e+i**2
    else:
        o=o+i**3
print('sum of even',e)
print('sum of odd',o)
# Out:
# sum of even 20
# sum of odd 153

# %%
L=[1,2,3,4,5,6,7,8,0,9]
