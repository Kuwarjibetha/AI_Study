# %%
f=open('abc.txt','w')
f.write('hello')
f.close()

# %%
f=open('xyz.txt','w')
f.write('hello')
f.write('hii')
f.write('heyy')
f.close()

# %%
f=open('123.doc','w')
f.write('hello\n')
f.write('hii\n')
f.write('heyy')
f.close()

# %%
f=open('city.doc','w')
f.write('delhi\n')
f.write('noida\n')
f.write('pune\n')
f.write('agra\n')
f.close()

# %%
f=open('city.doc','r')
# print(f.readline())
# print(f.readlines())

# print(f.read(2))


print(f.read())
print(f.readlines())

f.close()
# Out:
# delhi
# noida
# pune
# agra
#
# []

# %%
L=['python\n','ml\n','ai\n','sql\n','excel\n','nlp\n']

f=open('course.docx','w')
f.writelines(L)

f.close()

# %%
f=open('city.doc','a')
f.write('ooty\n')
f.close()

# %%
f=open('course.docx','a')
f.write('gen ai\n')
print(f.closed)
f.close()
print(f.closed)
# Out:
# False
# True

# %%
with open('100.txt','w') as f:
    f.write('hii')
# Out:
# False
# True

# %%
f=open('city.doc','r')
L=f.readlines()
print(L)
s=input('enter your search ')
s=s+'\n'

if s in L:
    print('found')
else:
    print('not found')
    choice=input('enter yes or no to add ')
    if choice=='yes':
        with open('city.doc','a') as f:
            f.write(s)
            print('Added')
    else:
        print('ok')
# Out:
# ['delhi\n', 'noida\n', 'pune\n', 'agra\n', 'ooty\n']
# enter your search  gurgaon
# not found
# enter yes or no to add  yes
# Added

# %%
f=open('C:\\Users\\cipl\\Desktop\\desk.doc','w')
f.write('ooty\n')
f.close()

# %%
f=open('C:/Users/cipl/Desktop/test.txt')
print(f.read())
f.close()
# Out:
# dffwe
# effgresf
# asgf
# fagr
# wdfgews

# %%
import os

# %%
os.rename('abc.txt','ijk.doc')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 os.rename('abc.txt','ijk.doc')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'abc.txt' -> 'ijk.doc'

# %%
os.rename('abc.txt','ijk.doc')

# %%
# os.rename('C:\\Users\\cipl\\Desktop\\desk.doc','deepanshu.doc')

# %%
os.remove('xyz.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 os.remove('xyz.txt')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'xyz.txt'

# %%
os.mkdir('new1')

# %%
os.mkdir('new1\\new2')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cipl\\weekday 10\\FILE HANDLING'

# %%
os.rmdir('new1')
