# %% [markdown]
# # Loops

# %%
# for loop
# while loop

# %%
# for loop
#1. when i want to iterate in a given iterable we use for loop for it
    # when i want to move charcater by character in a given sequence we use for loop foir it

#2. when i want to do the task at certain number of times we use for loop for it

# %%
n='aman'
for i in n:
    print(i)
# Out:
# a
# m
# a
# n

# %%
n='aman'
for i in n:
    print(i)
    print('hello')
# Out:
# a
# hello
# m
# hello
# a
# hello
# n
# hello

# %%
n='aman'
for i in n:
    print(i)

print('bye')
# Out:
# a
# m
# a
# n
# bye

# %%
n='aman'
for i in n:
    print(n)
# Out:
# aman
# aman
# aman
# aman

# %%
n=input('enter name ')

for i in n:
    print(i)
print('Bye')
# Out:
# enter name  deepanshu
# d
# e
# e
# p
# a
# n
# s
# h
# u
# Bye

# %%
n='ape'
c=0
for i in n:
    c=c+1

print(c)
# Out:
# 3

# %%
n='ape'
c=0
for i in n:
    c=c+1

    print(c)
# Out:
# 1
# 2
# 3

# %%
n=input('enter n ')
c=0
for i in n:
    c=c+1
    print(i,c)
# Out:
# enter n  deepanshu
# d 1
# e 2
# e 3
# p 4
# a 5
# n 6
# s 7
# h 8
# u 9

# %%
L=[1,2,3,4,5,6,7,8,0,9]
c=0
for i in L:
    c+=1 # c=c+1

print(c)
# Out:
# 10

# %%
L=[1,2,3,4,5,6,7,8,0,9]
s=0
c=0
for i in L:
    s=s+i
    c+=1 # c=c+1

print(s/c)
# Out:
# 4.5

# %%
L=[1,2,3,4,5]
e=0
o=0
for i in L:
    if i%2==0:
        e=e+i**2
    else:
        o=o+i**3
print('sum of even',e)
print('sum of odd',o)
# Out:
# sum of even 20
# sum of odd 153

# %%
L=[1,2,3,4,] # 
s=0
ce=0
o=0
co=0
for i in L:
    if i%2==0:
        s+=i # s=s+i
        ce+=1 # ce=ce+1
    else:
        o=o+i
        co+=1

print('Average iof even numbers',s/ce)
print('Average oif odd numbers',o/co)
# Out:
# Average iof even numbers 3.0
# Average oif odd numbers 2.0

# %%
n=input('enter name ')
v=0
c=0
for i in n:
    if i=='a' or i=='e' or i=='o' or i=='i' or i=='u':
        v=v+1
    else:

        c+=1
print('Total vowels in',n,'is',v)
print('Total Consonants in',n,'is',c)
# Out:
# enter name  hello i am deepanshu
# Total vowels in hello i am deepanshu is 8
# Total Consonants in hello i am deepanshu is 12

# %%
n=int(input('enter n '))

for i in range(1,n+1):
    print('Deepanshu',i)
# Out:
# enter n  9
# Deepanshu 1
# Deepanshu 2
# Deepanshu 3
# Deepanshu 4
# Deepanshu 5
# Deepanshu 6
# Deepanshu 7
# Deepanshu 8
# Deepanshu 9

# %%
n=int(input('enter n '))
s=0
for i in range(1,n+1):
    s=s+i
print(s/n)
# Out:
# enter n  6
# 3.5

# %%
n=int(input('enter n '))
se=0
so=0
for i in range(1,n+1):
    if i%2==0:
        se=se+i**2
    else:
        so=so+i**3

print(se)

print('odd',so)
# Out:
# enter n  5
# 20
# odd 153

# %%
n=int(input('enter n '))
for i in range(1,11):
    print(n,'*',i,'=',n*i)
# Out:
# enter n  7
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70

# %%
n=int(input('enter n '))
f=1
if n>0:
    for i in range(1,n+1):
        
        f=f*i
    print(f)

else:
    print('invalid')
# Out:
# enter n  6
# 720

# %%
n=int(input('enter n '))
c=0
for i in range(1,n+1):
    if n%i==0:
        c=c+1
        
if c==2:
    print(n,'is prime')
else:
    print(n,'is not prime')
# Out:
# enter n  12
# Factors of 12 is 1
# Factors of 12 is 2
# Factors of 12 is 3
# Factors of 12 is 4
# Factors of 12 is 5
# Factors of 12 is 6
# Factors of 12 is 7
# Factors of 12 is 8
# Factors of 12 is 9
# Factors of 12 is 10
# Factors of 12 is 11
# Factors of 12 is 12
# 12 is not prime

# %%
n=int(input('enter how many nunvber do you want '))
s=0
for i in range(1,n+1):
    a=int(input('enter a '))
    s=s+a
print(s/n)
# Out:
# enter how many nunvber do you want  5
# enter a  10
# enter a  100
# enter a  1000
# enter a  10000
# enter a  10000
# 4222.0
