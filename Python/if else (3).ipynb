# %%
print('\n')

# %%
print('\\n')
# Out:
# \n

# %%
a=10
b=1

a,b=b,a
print('a',a)
print('b',b)
# Out:
# a 1
# b 10

# %%
x=100
y=50
z=y
y=x
x=z

print('x',x)
print('y',y)
# Out:
# x 50
# y 100

# %%
r=int(input('enter radius '))
# pi=3.14
area=3.14*r**2
print(area)
# Out:
# enter radius  5
# 78.5

# %%
a=int(input('enter a '))

s=a+a+a
print(s*3)
# Out:
# enter a  2
# 18

# %%
b=3
p=4
c=((b**2)+(p**2))**0.5
print(c)
# Out:
# 5.0

# %%
print('hello')
print('i')
print('am')
print('Deepanshu')
# Out:
# hello
# i
# am
# Deepanshu

# %%
if condition:
    statment

    
else:
    statement

# %%
n=int(input('enter n '))

if n>0:
    print(n,'is positive')

else:
    print(n,'is negative')
# Out:
# enter n  0
# 0 is negative

# %%
n=int(input('enter n '))

if n%2==0:
    print(n,'is even')
else:
    print(n,'is odd')
# Out:
# enter n  9
# 9 is odd

# %%
a=int(input('enter a '))
b=int(input('enter b '))

if a>b:
    print(a,'is greater than',b)
else:
    print(b,'is greater than',a)
# Out:
# enter a  20
# enter b  30
# 30 is greater than 20

# %%
# multiple codnition

if condtion:
    statment

elif condition:
    statement

elif condition:
    statement


elif condition:
    statement



else:
    statemnt

# %%
n=int(input('enter n '))

if n>0:
    print(n,'is positive')

elif n==0:
    print(n,'is neutral')

else:
    print(n,'is negative')
# Out:
# enter n  0
# 0 is neutral

# %%
a=int(input('enter a '))
b=int(input('enter b '))

if a>b:
    print(a,'is greater than',b)

elif a==b:
    print(a,'is equal to',b)
else:
    print(b,'is greater than',a)
# Out:
# enter a  10
# enter b  10
# 10 is equal to 10

# %%
a=?
b=?
c=# +, -, *

# %%
a=int(input('enter a '))
b=int(input('enter b '))
c= input('enter operator ')

if c=='+':
    print(a+b)

elif c=='-':
    print(a-b)

elif c=='*':
    print(a*b)

else:
    print('invalid')
# Out:
# enter a  3
# enter b  4
# enter operator  *
# 12

# %%
a=int(input('enter a '))
b=int(input('enter b '))
c=int(input('enter c '))

if a>b and a>c:
    print(a,'is greater than',b,c)
elif b>a and b>c:
    print(b,'is greatert than',a,c)
else:
    print(c,'is greater than',a,b)
# Out:
# enter a  10
# enter b  30
# enter c  20
# 30 is greatert than 10 20

# %%
m=?
m in between 90-100 A
m in between 70-90 B
m in between 50-70 C
m in between 30-50 D
m 30 lesser E

# %%
m=int(input('enter marks '))
if m>90 and m<=100:
    print('A')

elif m>70 and m<=90:
    print('B')

elif m>50 and m<=70:
    print('C')

elif m>30 and m<=50:
    print('D')

else:
    print('E')
# Out:
# enter marks  45
# D

# %%
days=input('enter days ')
# sunday, satruday----weekend
# monday, tuesday, wedensday -----weekday
if days=='saturday' or days=='sunday':
    print('Weekend')
elif days=='monday' or days=='tuesday' or days=='wedensday':
    print('Weekdays')
else:
    print('Invalid')
# Out:
# enter days  saturday
# Weekend

# %%
# sal=?
# sal lesser 25k ----0%-----Net sal
# sal 25k ----50k------10%-----Net sal
# sal 50k---100k----- 25%-----Net sal
# sal greater 100k-----50%----Net sal

# %%
sal=int(input('enter salary '))
if sal<25000:
    print(sal-(sal*0)/100)

elif sal>=25000 and sal<50000:
    print(sal-(sal*10)/100)

elif sal>=5000 and sal<=100000:
    print(sal-(sal*25)/100)

else:
    print(sal-(sal*50)/100)
# Out:
# enter salary  200000
# 100000.0

# %%
n=?
n- 5,7---------diudivsible by both 5,7
n---5---------divisible by 5 only
n---7--------divisble by 7 only
none of them

# %%
n=int(input('enter n '))
if n%5==0:
    print(n,'is divisble by both 5 noly')
elif n%5==0 and n%7==0:
    print(n,'is divisble by noth 5,7 only')
elif n%7==0:
    print(n,'si divible by 7 only')
else:
    print('NOne Of them')
# Out:
# enter n  35
# 35 is divisble by both 5 noly

# %%
# Nested Condition

if con:
    if con:
        stmnt
    elif con:
        stmnt
    else:
        stmnt


elif con:
    if con:
        stmnt
    elif con:
        stmnt
    else:
        stmnt


else:
    if con:
        stmnt
    elif con:
        stmnt
    else:
        stmnt

# %%
n=int(input('enter n '))
if n%5==0:
    if n%7==0:
        print(n,'is dibisbilbe buy both 5 and 7')

    else:
        print(n,'is divible by 5 only')

elif n%7==0:
    print(n,'is divible by 7 only')

else:
    print('None og them')
# Out:
# enter n  35
# 35 is dibisbilbe buy both 5 and 7

# %%
w=# sunny, winter, rainy, invalid
w--- suny---temp ?  25-40k Not play otherwise play
w--- winter--temp >--- 10-20 play otherwise Not play
w--- raint----con---- heavy---Not play otherwise play

# %%
w=input('enter weather ')
if w=='sunny':
 temp=int(input('enter temperature '))
 if temp>=25 and temp<=40:
     print('Not Play')
 else:
    print('Play')

elif w=='winter':
    temp=int(input('enter temperature '))
    if temp>=10 and temp<=20:
        print('Play')
    else:
        print('Not play')

elif w=='rainy':
    con=input('enter rainy condition')
    if con=='heavy':
        print('Not play')
    else:
        print('plkay')


else:
    print('invalid')
# Out:
# enter weather  rainy
# enter rainy condition normal
# plkay

# %%
# n=?
# if n is odd then it display weired
# if n is even , and in between 2 to 5 then it display Not werired
# if n is even , and in between 5 to 20 then it dispalyt weired
# if n is even , and greater than 20 then it display Not werired

# %%
n=int(input('enter n '))
if n%2!=0:
    print('weired')

else:
    if n>=2 and n<5:
        print('Not weired')
    elif n>5 and n<=20:
        print('weired')
    else:
        print('Not weried')
# Out:
# enter n  18
# weired

# %%
order=? 
pizza---top---veggies, corn, cheese 
burger----cate---veg 80 not veg-150
pasta----sau---red , white

# %%
print('Available item pizza, burger, pasta')
order=input('Place your order ')

if order=='pizza':
    top=input('select toppings veggies , corn , cheese ')
    if top=='veggies':
        print('your',top,order,'price is 120')
    elif top=='corn':
         print('your',top,order,'price is 180')
    elif top=='cheese':
         print('your',top,order,'price is 220')
    else:
        print(top,order,'is not available')

elif order=='burger':
    cat=input('veg or non veg')
    if cat=='veg':
        print('your',cat,order,'price is 80')
    else:
        print('your',cat,order,'price is 130')


elif order=='pasta':
    sau=input('slect sauce red, white')
    if sau=='red':
        print('your',sau,'sauce',order,'price is 140')
    elif sau=='white':
        print('your',sau,'sauce',order,'price is 150')
    else:
        print(sau,'sauce',order,'is not availablr')
        
        
else:
    print('Not in a menu')
# Out:
# Available item pizza, burger, pasta
# Place your order  noodles
# Not in a menu

# %%
# ATM

# %%
print('Welcome to SBI ATM')
pin=int(input('enter pin '))
bal=1000
if pin==1234:
    print('Press 1 for check balance \nPress 2 for deposit\nPress 3 for withdrawl')

    opt=int(input('enter option '))
    if opt==1:
        print('your account balance is',bal)
    elif opt==2:
        amt=int(input('enter amt to deposit'))
        print('your final balance is',bal+amt)
    elif opt==3:
        amt=int(input('ernter amt ot withdrawl'))
        if amt<=bal:
            print('your final balance is',bal-amt)
        else:
            print('Insuffiecitn amt')
    
    
    else:
        print('not in option')



else:
    print('incoreect pin')
# Out:
# Welcome to SBI ATM
# enter pin  1234
# Press 1 for check balance
# Press 2 for deposit
# Press 3 for withdrawl
# enter option  2
# enter amt to deposit 6437
# your final balance is 7437
