# %%
print('hello')
# Out:
# hello

# %%
print("hii")
# Out:
# hii

# %%
print('vhdvds47682&%*(*')
# Out:
# vhdvds47682&%*(*

# %%
print('hello Deepanshu')
# Out:
# hello Deepanshu

# %%
print("hello 'Deepanshu' ")
# Out:
# hello Deepanshu'

# %%
print('"hello" Deepanshu')
# Out:
# "hello" Deepanshu

# %%
print('hello "Deepanshu"')
# Out:
# hello "Deepanshu"

# %%
print("'hello' Deepanshu")
# Out:
# 'hello' Deepanshu

# %%
print('\\n')
# Out:
# \n

# %%
print("\\n")
# Out:
# \n

# %%
print('hello',end='.')
print('Deepanshu',end=',')
print('verma')
# Out:
# hello.Deepanshu,verma

# %%
x=10 # storing 10 in variable x
#print(x)
#print('x')
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 x=10 # storing 10 in variable x
#       2 #print(x)
#       3 #print('x')
# ----> 4 print(y)
#
# NameError: name 'y' is not defined

# %%
# Rules for making the varibale

# %%
# varibale nae can be alpoahbetically
xyz=10
print(xyz)
# Out:
# 10

# %%
# varibale name can be in lower or upper case
AbcDe=10
print(AbcDe)
# Out:
# 10

# %%
# Variable name can be alpha numweric
abcd123=567
print(abcd123)
# Out:
# 567

# %%
# variable name cant start with the numbers
123xyz=100
print(123xyz)
# Out:
#   Cell In[39], line 1
#     123xyz=100
#       ^
# SyntaxError: invalid decimal literal

# %%
# variable name  cant contsain the special charcetr
abc*d=9
pribnt(abc*d)
# Out:
#   Cell In[41], line 2
#     abc*d=9
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# in speical character undescore can contain inyour variable
abc_d=5
print(abc_d)
# Out:
# 5

# %%
_123=567
print(_123)
# Out:
# 567

# %%
123_=10
print(123_)
# Out:
#   Cell In[44], line 1
#     123_=10
#        ^
# SyntaxError: invalid decimal literal

# %%
abc_=67
print(abc_)
# Out:
# 67

# %%
_=10
print(_)
# Out:
# 10

# %%
a b=100
print(a b)
# Out:
#   Cell In[47], line 1
#     a b=100
#       ^
# SyntaxError: invalid syntax

# %%
# pre defined keywords canrt be your variable name
for=50
print(for)
# Out:
#   Cell In[51], line 1
#     for=50
#        ^
# SyntaxError: invalid syntax

# %%
For=90
print(For)
# Out:
# 90

# %%
x=10
print('The value of x is',x)
# Out:
# The value of x is 10

# %% [markdown]
# ## dfgsbd/

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # Data Types

# %%
# Integer int All +ve to - ve numbers ex: 10, 50, -40
# Float   float  All decimal numbers ex: 3.5, 10.0, -5.7
# String  str   Anything that are in qouotation alwsy be my string 'abc','123', 'abc34%^'
# boolean  bool True, False

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
y='5.2'
print(type(y))
# Out:
# <class 'str'>

# %%
a=10
b='10'

print(a,type(a))
print(b,type(b))
# Out:
# 10 <class 'int'>
# 10 <class 'str'>

# %%
z=6.0
print('The data type of',z,'is',type(z))
# Out:
# The data type of 6.0 is <class 'float'>

# %%
z=False
print(type(z))
# Out:
# <class 'bool'>

# %%
d=56
print('The Data type of',d,'is',type(d))
# Out:
# The Data type of 56 is <class 'int'>

# %%
z=True
print('the data type of',z,'is',type(z))
# Out:
# the data type of True is <class 'bool'>

# %% [markdown]
# # Type Casting

# %%
a=10.3

b=int(a)
print(b,type(b))
# Out:
# 10 <class 'int'>

# %%
s=100
d=float(s)
print(d,type(d))
# Out:
# 100.0 <class 'float'>

# %%
x=5
y=str(x)
print(y,type(y))
# Out:
# 5 <class 'str'>

# %%
# convert '5' into float
# convert 10.5 into a string
# convert 6 into float
# convert '4.6' into integer

# %%
a='5'
b=float(a)
print(b,type(b))
# Out:
# 5.0 <class 'float'>

# %%
b=10.5
e=str(b)
print(e,type(e))
# Out:
# 10.5 <class 'str'>

# %%
x=6
y=float(x)
print(y,type(y))
# Out:
# 6.0 <class 'float'>

# %%
a='4.6'
b=float(a)
c=int(b)
print('The data type of',a,'is',type(a))
print('The data type of',b,'is',type(b))
print('The data type og',c,'is',type(c))
# Out:
# The data type of 4.6 is <class 'str'>
# The data type of 4.6 is <class 'float'>
# The data type og 4 is <class 'int'>

# %%
a=input('enter the value of a ')
print(a,type(a))
# Out:
# enter the value of a  5
# 5 <class 'str'>

# %%
b = int(input('enter the value of b '))
print(b,type(b))
# Out:
# enter the value of b  5
# 5 <class 'int'>

# %%
c= float(input('enter the value of  c ' ))
print(c,type(c))
# Out:
# enter the value of  c  1
# 1.0 <class 'float'>

# %%
name= input('enrter your name ')
print('My name is',name)
# Out:
# enrter your name  Deepanshu
# My name is Deepanshu

# %%
age = int(input('enter age '))
print('My age is',age)
# Out:
# enter age  6548
# My age is 6548

# %%
marks =float(input('enter marks '))
print('My marks are ',marks)
# Out:
# enter marks  5488
# My marks are  5488.0
