# %% [markdown]
# # Operator

# %% [markdown]
# operators are my symbols that performs the certain operations

# %%
# Types of Operators
# 1. Arithmetic Operators
# 2. Assingment Operators, Compound Assingment
# 3. Comparison Operators
# 4. Logical Operators
# 5. Identity Operators
# 6. Membership Operators

# %%
# Arithmetic Operators - are responsbile for mathematical calculations
# Addition +
# Subtraction -
# Multiplication *
# Single Division /
# Double Division //
# Modulus %
# Exponential **

# %%
a=int(input('enter the value of a '))
b=int(input('enter the value of b '))
# Out:
# enter the value of a  6
# enter the value of b  4

# %%
print(a)
print(b)
# Out:
# 6
# 4

# %%
print('The Addition of',a,'+',b,'=',a+b)
# Out:
# The Addition of 6 + 4 = 10

# %%
print('The Subtraction of',a,'-',b,'=',a-b)
# Out:
# The Subtraction of 6 - 4 = 2

# %%
print(a*b)
# Out:
# 24

# %%
print(a/b) # always return in float
# Out:
# 1.5

# %%
print(a//b) # alwsy return in int
# Out:
# 1

# %%
print(a%b) #remainder
# Out:
# 2

# %%
print(a**b) # power
# Out:
# 1296

# %%
x=10
y=10
print(x/y)
print(x%y)
# Out:
# 1.0
# 0

# %%
a=3
b=10
print(a%b)
# Out:
# 3

# %%
x=10
y=3
print(x%y)
# Out:
# 1

# %%
# Precendence of Operators

#(), **, *, /, //, %, + , -
#PEMDAS

# %%
# BODMAS

# %%
a=10
b=4
c=a-b+20
print(c)
# Out:
# 26

# %%
exp= 1+4*3/2-2
print(exp)
# Out:
# 5.0

# %%
# calculate the area of rectangle in which you take length and breadth as input
l=int(input('enter length '))
b=int(input('enter breadth '))
area=l*b
print('Area of Rectangle is',area)
# Out:
# enter length  4
# enter breadth  7
# Area of Rectangle is 28

# %%
# Assingment Operators - are responsible for assigning values to my variable

# =

# %%
a=10
print(a)
# Out:
# 10

# %%
# compound assingment
x=12
x+=2    #x=x+2
print(x)
# Out:
# 14

# %%
z=10
z-=10 # z=z-10
print(z)
# Out:
# 0

# %%
c=5
c**=3 # c=c**3
print(c)
# Out:
# 125

# %%
# Comparison Operator - resposible for comparing the values of the variable

# equal to ==
# Not equal to !=
# greater than >
# less than <
# greatere than equal to >=
# less than equal to <=

# %%
a=10
b=15

# print(a==b)
# print(a!=b)
# print(a>b)
# print(a<b)
# print(a>=b)
# print(a<=b)

# %%
x=20
y=20

# print(x!=y)
# print(x<y)
# print(x==y)
# print(x>=y)
# print(x>y)
# print(x<=y)

# %%
# Logical Operator - are resposible for coampring the boolean values of the variable
# and - when both the conditon are True resulrt will be True
# or - when any one condtion is True result will hbe True
# not - it reverts the operation
#             True--------False
#             False-------True

# %%
a=True
b=False
c=True
d=False

# print(a and b)
# print(b and d)
# print(a and c)
# print(a or  b)
# print(b and d)
# print(a and c)

# print(not a)
# print(not b)

# %%
# Identity Operators
# == comapinf variable values
# is  it compares the addres oif the variable

# %%
x=10
y=10.0

print(x==y)
print(x is y)
# Out:
# True
# False

# %%
print(id(x))
print(id(y))
# Out:
# 140712011774680
# 2394882186480

# %%
z=20
y=20

print(z is y)
print(id(z))
print(id(y))
# Out:
# True
# 140712011775000
# 140712011775000

# %%
s=100
t=100

print(s is t)
print(id(s))
print(id(t))
# Out:
# True
# 140712011777560
# 140712011777560

# %%
a=257
b=257
print(a==b)
print(a is b)
# Out:
# True
# False

# %%
a=256
b=256
print(a==b)
print(a is b)
# Out:
# True
# True

# %%
c=11
d=12
print(id(d))
print(id(c))
# Out:
# 140712011774744
# 140712011774712

# %%
# Membership Operators - are responsible to check whether the given string is present in sequence or not

# in

# %%
s='deepanshu'

# print('a' in s)
# print('k' in s)
# print('D' in s)
print('a' not in s)
print('k' not in s)
print('D'  not in s)
# Out:
# False
# True
# True
